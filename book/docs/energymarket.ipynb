# %% [markdown]
# # Energy Industry Overview

# %% [markdown]
# {badge}`python3,badge-success` {badge}`case study,badge-secondary` {badge}`electricity market,badge-warning`

# %% [markdown]
# Working with these files can be a challenge, especially given their heterogeneous nature. Some preprocessing is required before they are ready for consumption by your CNN.
#
# Fortunately, I participated in the LUNA16 competition as part of a university course on computer aided diagnosis, so I have some experience working with these files. At this moment we top the leaderboard there :)
#
# **This article provides an exploratory data analysis on the Philippine electricity market by comparing the data provided by IEMOP and DOE on their websites.**
#
# What we will cover:
#
# 1. **Pre-processing:** and adding missing metadata
# 2. **Exploratory Data Analysis:** and what tissue these unit values correspond to
# 3. **Resampling** to an isomorphic resolution to remove variance in scanner resolution.
#
# **Dataset:** The HR Dataset was designed by Drs. Rich Huebner and Carla Patalano to accompany a case study designed for graduate HR students studying HR metrics, measurement, and analytics. The students use Tableau data visualization software to uncover insights about the case. This is a synthetic data set created specifically to go along with the case study (proprietary for the college that we teach at). https://rpubs.com/rhuebner/hr_codebook_v14
#
# ***

# %% [markdown]
# ## Data Extraction
#
# The data comes from the published market participants list by IEMOP, the electricity market operator of the Philippines.

# %% [markdown]
# Cache the data; check if extracted is equal to imported, if not get the difference, then run the geocoding

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import altair as alt

# %%
# Formatting of DataFrame html view
t_props = [
  ('font-size', '80%')
  ]
   
styles = [
  dict(selector="th", props=t_props),
  dict(selector="td", props=t_props)
  ]

# %%
def get_data(url):
    html_data = pd.read_html(url)
    data = html_data[0]
    return data

# %%
df_wesm = get_data('http://www.iemop.ph/the-market/participants/wesm-members/')
# Dropping 451 Team Sual NA Resource value
df_wesm = df_wesm.dropna()

# %%
df_retail = get_data('http://www.iemop.ph/the-market/participants/rcoa-tp/')
df_retail = df_retail.dropna()

# %%
# load a simple dataset as a pandas DataFrame
from vega_datasets import data
cars = data.cars()

alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
)
# Out:
# alt.Chart(...)

# %%
df_wesm.describe()
# Out:
#                                          PARTICIPANT NAME SHORT NAME REGION  \
# count                                                 454        454    454
# unique                                                308        320      4
# top     Power Sector Assets & Liabilities Management C...      PSALM  LUZON
# freq                                                   20         20    277
#
#          CATEGORY MEMBERSHIP                   RESOURCE EFFECTIVE DATE  \
# count         454        454                        454            454
# unique          5          2                        443            245
# top     GENERATOR     DIRECT  Palauig Solar Power Plant     12/26/2010
# freq          292        388                          3             59
#
#             STATUS
# count          454
# unique           4
# top     REGISTERED
# freq           420

# %%
df_retail.describe()
# Out:
#                          NAME SHORT NAME REGION              CATEGORY  \
# count                    1668       1668   1668                  1668
# unique                   1457       1668      3                     6
# top     Megaworld Corporation    LXMRK2R  Luzon  Contestable Customer
# freq                       12          1   1443                  1507
#
#        MEMBERSHIP EFFECTIVE DATE      STATUS
# count        1668           1668        1668
# unique          3            199           2
# top      Indirect      26-Jun-13  Registered
# freq         1537            222        1622

# %%
df_wesm.dtypes
# Out:
# PARTICIPANT NAME    object
# SHORT NAME          object
# REGION              object
# CATEGORY            object
# MEMBERSHIP          object
# RESOURCE            object
# EFFECTIVE DATE      object
# STATUS              object
# dtype: object

# %% [markdown]
# ### Exploratory Data Analysis
#
# We explore the dataset by looking at each column; looking at unique values, calculating summaries, and plotting distributions.

# %% [markdown]
# ### Wholesale Electricity Spot Market
#
# This section discusses the data on Wholesale Electricity Spot Market participants.

# %% [markdown]
# First, we look at the column names to see the variables from the data. We get the counts of the unique values in each column.

# %% [markdown]
# #### Participant Name and Short Name
#
# From the counts above, we notice that `PARTICIPANT NAME` and `SHORT NAME` are not equal. This means that there are duplicate values for these variables. We investigate by performing a cross-tabulation.

# %%
df_cross = pd.crosstab(df_wesm['SHORT NAME'], df_wesm['PARTICIPANT NAME'],margins=True)
df_cross.tail().style.set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_b6948156_2acf_11eb_ba32_8c2937e74e7a th {
#           font-size: 80%;
#     }    #T_b6948156_2acf_11eb_ba32_8c2937e74e7a td {
#           font-size: 80%;
#     }</style><table id="T_b6948156_2acf_11eb_ba32_8c2937e74e7a" ><thead>    <tr>        <th class="index_name level0" >PARTICIPANT NAME</th>        <th class="col_heading level0 col0" >1590 Energy Corporation</th>        <th class="col_heading level0 col1" >AC Energy Philippines, Inc.</th>        <th class="col_heading level0 col2" >AES Philippines Inc.</th>        <th class="col_heading level0 col3" >AP Renewables Inc.</th>        <th class="col_heading level0 col4" >AP Renewables Inc. (APRI-Unocal Philippines)</th>        <th class="col_heading level0 col5" >Aboitiz Energy Solution Inc.</th>        <th class="col_heading level0 col6" >Abra Electric Cooperative Inc.</th>        <th class="col_heading level0 col7" >Absolut Distillers Inc.</th>        <th class="col_heading level0 col8" >Aklan Electric Cooperative Inc.</th>        <th class="col_heading level0 col9" >Albay Electric Cooperative Inc.</th>        <th class="col_heading level0 col10" >Alternergy Wind One Corporation</th>        <th class="col_heading level0 col11" >Alterpower Digos Solar Inc.</th>        <th class="col_heading level0 col12" >Amlan Hydroelectric Power Corporation</th>        <th class="col_heading level0 col13" >Anda Power Corporation</th>        <th class="col_heading level0 col14" >Angat Hydropower Corporation</th>        <th class="col_heading level0 col15" >Angeles Electric Corporation</th>        <th class="col_heading level0 col16" >Angeles Power Inc.</th>        <th class="col_heading level0 col17" >Antique Electric Cooperative Inc.</th>        <th class="col_heading level0 col18" >Armed Forces of the Philippines-Philippine Air Force (560th Air Base Wing Brigadier General Benito N. Ebuen Air Base)</th>        <th class="col_heading level0 col19" >Aseagas Corporation</th>        <th class="col_heading level0 col20" >Asia Pacific Energy Corporation</th>        <th class="col_heading level0 col21" >Asian Carbon Neutral Power Corp.</th>        <th class="col_heading level0 col22" >Asian Greenenergy Corp.</th>        <th class="col_heading level0 col23" >Astronergy Development Gensan Inc.</th>        <th class="col_heading level0 col24" >Aurora Electric Cooperative Inc.</th>        <th class="col_heading level0 col25" >Authority of the Freeport Area of Bataan</th>        <th class="col_heading level0 col26" >BOHECO I Sevilla Mini Hydro Corp.</th>        <th class="col_heading level0 col27" >Babcock-Hitachi Philippines Inc.</th>        <th class="col_heading level0 col28" >Bac-Man Geothermal Inc.</th>        <th class="col_heading level0 col29" >Balamban Enerzone Corporation</th>        <th class="col_heading level0 col30" >Bataan 2020 Power Ventures Inc.</th>        <th class="col_heading level0 col31" >Bataan 2020, Inc.</th>        <th class="col_heading level0 col32" >Batangas Bay Terminal Inc.</th>        <th class="col_heading level0 col33" >Batangas City Water District</th>        <th class="col_heading level0 col34" >Batangas I Electric Cooperative Inc.</th>        <th class="col_heading level0 col35" >Batangas II Electric Cooperative Inc.</th>        <th class="col_heading level0 col36" >Benguet Corporation</th>        <th class="col_heading level0 col37" >Benguet Electric Cooperative Inc.</th>        <th class="col_heading level0 col38" >Bicol Biomass Energy Corporation</th>        <th class="col_heading level0 col39" >Bicol Ice Incorporated</th>        <th class="col_heading level0 col40" >Biliran Electric Cooperative Inc.</th>        <th class="col_heading level0 col41" >Biscom Inc.</th>        <th class="col_heading level0 col42" >Bohol Enterprise Inc.</th>        <th class="col_heading level0 col43" >Bohol I Electric Cooperative - Janopol Mini Hydro Power Coporation</th>        <th class="col_heading level0 col44" >Bohol I Electric Cooperative Inc.</th>        <th class="col_heading level0 col45" >Bohol II Electric Cooperative Inc.</th>        <th class="col_heading level0 col46" >Bohol Light Company Inc.</th>        <th class="col_hea ...

# %% [markdown]
# Based on the tabulation, we can see that there are `PARTICIPANT NAME` with multiple `SHORT NAME`.

# %%
df_cross.All[(df_cross.All > 1)].head(n=10)
# Out:
# SHORT NAME
# AFAB                  2
# AHC                   2
# APRI                 10
# BGI                   2
# CEDC                  3
# CENPRI                4
# EDC                   3
# FDC                   3
# FGHPC                 3
# FGP - San Lorenzo     2
# Name: All, dtype: int64

# %% [markdown]
# We take a look at some of the values.

# %%
df_wesm[df_wesm['SHORT NAME'] =='APRI'].tail().style.set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7a th {
#           font-size: 80%;
#     }    #T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7a td {
#           font-size: 80%;
#     }</style><table id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PARTICIPANT NAME</th>        <th class="col_heading level0 col1" >SHORT NAME</th>        <th class="col_heading level0 col2" >REGION</th>        <th class="col_heading level0 col3" >CATEGORY</th>        <th class="col_heading level0 col4" >MEMBERSHIP</th>        <th class="col_heading level0 col5" >RESOURCE</th>        <th class="col_heading level0 col6" >EFFECTIVE DATE</th>        <th class="col_heading level0 col7" >STATUS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7alevel0_row0" class="row_heading level0 row0" >62</th>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow0_col0" class="data row0 col0" >AP Renewables Inc.</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow0_col1" class="data row0 col1" >APRI</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow0_col2" class="data row0 col2" >LUZON</td>
#             </tr>
#             <tr>
#                         <th id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7alevel0_row3" class="row_heading level0 row3" >65</th>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow3_col0" class="data row3 col0" >AP Renewables Inc.</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow3_col1" class="data row3 col1" >APRI</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow3_col2" class="data row3 col2" >LUZON</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow3_col3" class="data row3 col3" >GENERATOR</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow3_col4" class="data row3 col4" >DIRECT</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow3_col5" class="data row3 col5" >Tiwi Geothermal Power Plant C</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow3_col6" class="data row3 col6" >05/26/2009</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow3_col7" class="data row3 col7" >REGISTERED</td>
#             </tr>
#             <tr>
#                         <th id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7alevel0_row4" class="row_heading level0 row4" >395</th>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow4_col0" class="data row4 col0" >AP Renewables Inc.</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow4_col1" class="data row4 col1" >APRI</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow4_col2" class="data row4 col2" >LUZON</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow4_col3" class="data row4 col3" >GENERATOR</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow4_col4" class="data row4 col4" >DIRECT</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow4_col5" class="data row4 col5" >Makban Geothermal Power Plant B</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow4_col6" class="data row4 col6" >06/15/2019</td>
#                         <td id="T_b6ce4ab2_2acf_11eb_ba32_8c2937e74e7arow4_col7" class="data row4 col7" >REGISTERED</td>
#             </tr>
#     </tbody></table>

# %%
df_wesm[df_wesm['SHORT NAME'] =='AHC'].tail().style.set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_b7142e06_2acf_11eb_ba32_8c2937e74e7a th {
#           font-size: 80%;
#     }    #T_b7142e06_2acf_11eb_ba32_8c2937e74e7a td {
#           font-size: 80%;
#     }</style><table id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PARTICIPANT NAME</th>        <th class="col_heading level0 col1" >SHORT NAME</th>        <th class="col_heading level0 col2" >REGION</th>        <th class="col_heading level0 col3" >CATEGORY</th>        <th class="col_heading level0 col4" >MEMBERSHIP</th>        <th class="col_heading level0 col5" >RESOURCE</th>        <th class="col_heading level0 col6" >EFFECTIVE DATE</th>        <th class="col_heading level0 col7" >STATUS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7alevel0_row0" class="row_heading level0 row0" >268</th>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow0_col0" class="data row0 col0" >Angat Hydropower Corporation</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow0_col1" class="data row0 col1" >AHC</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow0_col2" class="data row0 col2" >LUZON</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow0_col3" class="data row0 col3" >GENERATOR</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow0_col4" class="data row0 col4" >DIRECT</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow0_col5" class="data row0 col5" >Angat Hydro Electric Power Plant Unit A</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow0_col6" class="data row0 col6" >10/31/2014</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow0_col7" class="data row0 col7" >REGISTERED</td>
#             </tr>
#             <tr>
#                         <th id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7alevel0_row1" class="row_heading level0 row1" >269</th>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow1_col0" class="data row1 col0" >Angat Hydropower Corporation</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow1_col1" class="data row1 col1" >AHC</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow1_col2" class="data row1 col2" >LUZON</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow1_col3" class="data row1 col3" >GENERATOR</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow1_col4" class="data row1 col4" >DIRECT</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow1_col5" class="data row1 col5" >Angat Hydro Electric Power Plant Unit M</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow1_col6" class="data row1 col6" >10/31/2014</td>
#                         <td id="T_b7142e06_2acf_11eb_ba32_8c2937e74e7arow1_col7" class="data row1 col7" >REGISTERED</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# We can see that each `PARTICIPANT NAME` has multiple `RESOURCE` entries. From the inspected data above, we can infer that membership in the spot market is a disaggregation of the power plant units of each participating company.

# %% [markdown]
# #### Region
#
# We look at the `REGION` variable and see that most of the participants are from Luzon.

# %%
df_wesm.groupby('REGION')['RESOURCE'].nunique()
# Out:
# REGION
# LUZON              269
# LUZON / VISAYAS      9
# MINDANAO            38
# VISAYAS            128
# Name: RESOURCE, dtype: int64

# %%
df_retail.groupby('REGION')['NAME'].nunique()
# Out:
# REGION
# Luzon            1253
# Luzon/Visayas      34
# Visayas           176
# Name: NAME, dtype: int64

# %% [markdown]
# We look at the participants with dual regions.

# %%
df_wesm[df_wesm['REGION'] =='LUZON / VISAYAS'].tail().style.set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_ba5586f0_2acf_11eb_ba32_8c2937e74e7a th {
#           font-size: 80%;
#     }    #T_ba5586f0_2acf_11eb_ba32_8c2937e74e7a td {
#           font-size: 80%;
#     }</style><table id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PARTICIPANT NAME</th>        <th class="col_heading level0 col1" >SHORT NAME</th>        <th class="col_heading level0 col2" >REGION</th>        <th class="col_heading level0 col3" >CATEGORY</th>        <th class="col_heading level0 col4" >MEMBERSHIP</th>        <th class="col_heading level0 col5" >RESOURCE</th>        <th class="col_heading level0 col6" >EFFECTIVE DATE</th>        <th class="col_heading level0 col7" >STATUS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7alevel0_row0" class="row_heading level0 row0" >263</th>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow0_col0" class="data row0 col0" >National Grid Corporation of the Philippines</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow0_col1" class="data row0 col1" >NGCP</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow0_col2" class="data row0 col2" >LUZON / VISAYAS</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow0_col3" class="data row0 col3" >BULK USER</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow0_col4" class="data row0 col4" >DIRECT</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow0_col5" class="data row0 col5" >National Grid Corporation of the Philippines</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow0_col6" class="data row0 col6" >07/29/2014</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow0_col7" class="data row0 col7" >REGISTERED</td>
#             </tr>
#             <tr>
#                         <th id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7alevel0_row1" class="row_heading level0 row1" >358</th>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow1_col0" class="data row1 col0" >National Power Corporation</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow1_col1" class="data row1 col1" >NPC</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow1_col2" class="data row1 col2" >LUZON / VISAYAS</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow1_col3" class="data row1 col3" >GENERATOR</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow1_col4" class="data row1 col4" >DIRECT</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow1_col5" class="data row1 col5" >Power Barges</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow1_col6" class="data row1 col6" >09/25/2016</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow4_col4" class="data row4 col4" >DIRECT</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow4_col5" class="data row4 col5" >Angeles Power Inc.</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow4_col6" class="data row4 col6" >02/26/2020</td>
#                         <td id="T_ba5586f0_2acf_11eb_ba32_8c2937e74e7arow4_col7" class="data row4 col7" >CEASED</td>
#             </tr>
#     </tbody></table>

# %%
df_retail[df_retail['REGION'] =='Luzon/Visayas']
# Out:
#                                                    NAME SHORT NAME  \
# 101                                    GNPower Ltd. Co.   GNPLCRES
# 171                 Waterfront Mactan Casino Hotel Inc.    WAHCRES
# 179               GNPower Mariveles Coal Plant Ltd. Co.     GNPRES
# 220                           Millennium Power RES Inc.    MPRIRES
# 253            FDC Retail Electricity Sales Corporation    FDCRESC
# 254   AC Energy Inc. (formerly AC Energy Holdings Inc.)     ACERES
# 298                                   Manta Energy Inc.   MANTARES
# 299                  SMC Consolidated Power Corporation  SMCCPCRES
# 300                                      Corenergy Inc.    CORERES
# 370                         KEPCO SPC Power Corporation    KSPCRES
# 371                      Citicore Energy Solutions Inc.    CESIRES
# 373        Vantage Energy Solutions and Management Inc.   VESMIRES
# 383                        Mazzaraty Energy Corporation     MACRES
# 393                                         Solvre Inc.  SOLVRERES
# 705                             Bac-Man Geothermal Inc.     BGIRES
# 813                          Anda Power Corporation RES    ANDARES
# 914                          SEM-CALACA RES CORPORATION    SCRCRES
# 1103                                     MeridianX Inc.    MERXRES
# 1312                         Mabuhay Energy Corporation    MECORES
# 1323          Solar Philippines Retail Electricity Inc.   SPREIRES
# 1394               Premier Energy Resources Corporation    PERCRES
# 1395              TeaM (Philippines) Energy Corporation    TPECRES
# 1396                      PHINMA Energy Corporation-RES    PHENRES
# 1398            Masinloc Power Partners Company Limited   MPPCLRES
# 1399                                    Kratos RES Inc.  KRATOSRES
# 1402                      Aboitiz Energy Solutions Inc.    AESIRES
# 1403                                  AdventEnergy Inc.  ADVENTRES
# 1404                                  Prism Energy Inc.   PRISMRES
# 1416                    San Miguel Electric Corporation   SMELCRES
# 1417                          SN Aboitiz Power-RES Inc.    SNAPRES
# 1418                          DirectPower Services Inc.  DIRPOWRES
# 1419                    First Gen Energy Solutions Inc.    FGESRES
# 1423                      Ecozone Power Management Inc.    EPMIRES
# 1424                   Global Energy Supply Corporation    GESCRES
#
#              REGION                     CATEGORY MEMBERSHIP EFFECTIVE DATE  \
# 101   Luzon/Visayas  Retail Electricity Supplier     Direct      15-Apr-14
# 171   Luzon/Visayas  Retail Electricity Supplier     Direct      26-Oct-15
# 179   Luzon/Visayas  Retail Electricity Supplier     Direct      15-Mar-16
# 220   Luzon/Visayas  Retail Electricity Supplier     Direct      18-Aug-16
# 253   Luzon/Visayas  Retail Electricity Supplier     Direct      04-Oct-16
# 254   Luzon/Visayas  Retail Electricity Supplier     Direct      21-Oct-16
# 108                              San Miguel Corporation    SMC501R  Visayas
# 129            Central Negros Electric Cooperative Inc.  CENECOLRE  Visayas
# ...                                                 ...        ...      ...
# 1425                      Visayan Electric Company Inc.    VECOLRE  Visayas
# 1637  Masterpiece Asia Properties Inc. (Vistamall Ta...    MPAP14R  Visayas
# 1665  Dynasty Management and Development Corp. (Gais...    DMDC06R  Visayas
# 1666                                Sunpride Foods Inc.    SNPFI1R  Visayas
# 1667                   Capiz Electric Cooperative, Inc.  CAPELCMSP  Visayas
#
#                                CATEGORY        MEMBERSHIP EFFECTIVE DATE  \
# 32    Retail Metering Services Provider  Service Provider      25-Sep-13
# 33    Retail Metering Services Provider  Service Provider      25-Sep-13
# 94    Local Retail Electricity Supplier            Direct      20-Mar-14
# 108                Contestable Customer          Indirect      26-May-14
# 129   Local Retail Electricity Supplier            Direct      19-Aug-14
# ...                                 ...               ...            ...
# 1425  Local Retail Electricity Supplier            Direct      19-Jun-13
# 1637               Contestable Customer          Indirect      26-Aug-20
# 1665               Contestable Customer          Indirect      26-Oct-20
# 1666               Contestable Customer          Indirect      26-Oct-20
# 1667  Retail Metering Services Provider  Service Provider      11-Nov-20
#
#           STATUS
# 32    Registered
# 33    Registered
# 94    Registered
# 108   Registered
# 129   Registered
# ...          ...
# 1425  Registered
# 1637  Registered
# 1665  Registered
# 1666  Registered
# 1667  Registered
#
# [191 rows x 7 columns]

# %% [markdown]
# Except for the NGCP, which is a transmission company and NPC, all the participants with dual regions are Aggregators (WAG) with 'ceased' status. ERC has issued a circular to stop the operation of all WAGs.

# %%
df_wesm = df_wesm[df_wesm['REGION']!='LUZON / VISAYAS']

# %%
df_wesm.describe()
# Out:
#                                          PARTICIPANT NAME SHORT NAME REGION  \
# count                                                 445        445    445
# unique                                                300        311      3
# top     Power Sector Assets & Liabilities Management C...      PSALM  LUZON
# freq                                                   20         20    277
#
#          CATEGORY MEMBERSHIP                   RESOURCE EFFECTIVE DATE  \
# count         445        445                        445            445
# unique          4          2                        434            239
# top     GENERATOR     DIRECT  Palauig Solar Power Plant     12/26/2010
# freq          291        379                          3             59
#
#             STATUS
# count          445
# unique           4
# top     REGISTERED
# freq           419

# %% [markdown]
# #### Category
#
# Just like any market, we can see that WESM participants are either buyers or sellers of electricity.

# %%
df_wesm['CATEGORY'].unique()
# Out:
# array(['GENERATOR', 'PRIVATE DISTRIBUTION UTILITY',
#        'ELECTRIC COOPERATIVE', 'BULK USER'], dtype=object)

# %% [markdown]
# #### Membership
#
# Participants have either `DIRECT` or `INDIRECT` membership, which pertains to their grid connection status.

# %%
df_wesm['MEMBERSHIP'].unique()
# Out:
# array(['DIRECT', 'INDIRECT'], dtype=object)

# %% [markdown]
# #### Effective Date
#
# Date when they participated in the market. We convert the data type.

# %%
df_wesm = df_wesm.astype({'EFFECTIVE DATE': 'datetime64'})

# %%
df_retail = df_retail.astype({'EFFECTIVE DATE': 'datetime64'})

# %%
df_wesm
# Out:
#                   PARTICIPANT NAME         SHORT NAME    REGION  \
# 0       GNPower Kauswagan Ltd. Co.            GNPKLCO  MINDANAO
# 1       GNPower Kauswagan Ltd. Co.            GNPKLCO  MINDANAO
# 2                  FGP Corporation  FGP - San Lorenzo     LUZON
# 3                  FGP Corporation  FGP - San Lorenzo     LUZON
# 4      First Gas Power Corporation           FGPCSTRA     LUZON
# ..                             ...                ...       ...
# 450  FDC Misamis Power Corporation                FDC  MINDANAO
# 451  FDC Misamis Power Corporation                FDC  MINDANAO
# 452  FDC Misamis Power Corporation                FDC  MINDANAO
# 453    Malvar Enerzone Corporation             MALVEZ     LUZON
# 454      GNPower Dinginin Ltd. Co.               GNPD     LUZON
#
#                          CATEGORY MEMBERSHIP  \
# 0                       GENERATOR     DIRECT
# 1                       GENERATOR     DIRECT
# 2                       GENERATOR     DIRECT
# 3                       GENERATOR     DIRECT
# 4                       GENERATOR     DIRECT
# ..                            ...        ...
# 450                     GENERATOR     DIRECT
# 451                     GENERATOR     DIRECT
# 452                     GENERATOR     DIRECT
# 453  PRIVATE DISTRIBUTION UTILITY     DIRECT
# 454                     GENERATOR     DIRECT
#
#                                          RESOURCE EFFECTIVE DATE      STATUS
# 0              GNPK Coal Fired Power Plant Unit 4     2020-08-07  REGISTERED
# 1              GNPK Coal Fired Power Plant Unit 3     2020-08-07  REGISTERED
# 2           San Lorenzo Natural Gas Power Plant 5     2006-06-26  REGISTERED
# 3           San Lorenzo Natural Gas Power Plant 6     2006-06-26  REGISTERED
# 4             Sta. Rita Natural Gas Power Plant 1     2006-06-26  REGISTERED
# ..                                            ...            ...         ...
# 450  135 MW Coal Fired Thermal Power Plant Unit 1     2020-10-26  REGISTERED
# 451  135 MW Coal Fired Thermal Power Plant Unit 2     2020-10-26  REGISTERED
# 452  135 MW Coal Fired Thermal Power Plant Unit 3     2020-10-26  REGISTERED
# 453                   Malvar Enerzone Corporation     2020-10-30  REGISTERED
# 454                   GNPD Coal Fired Power Plant     2020-10-31  REGISTERED
#
# [445 rows x 8 columns]

# %% [markdown]
# #### Status
#
# We only consider participants with `REGISTERED` status

# %%
df_wesm['STATUS'].unique()
# Out:
# array(['REGISTERED', 'DEREGISTERED',
#        'REGISTERED; WITH NOTICE OF SUSPENSION', 'CEASED'], dtype=object)

# %%
df_retail['STATUS'].unique()
# Out:
# array(['Registered', 'Ceased'], dtype=object)

# %%
df_wesm = df_wesm[df_wesm['STATUS']=='REGISTERED']
df_retail = df_retail[df_retail['STATUS']=='Registered']

# %%
df_wesm['STATUS'].unique()
# Out:
# array(['REGISTERED'], dtype=object)

# %%
df_retail['STATUS'].unique()
# Out:
# array(['Registered'], dtype=object)

# %%
df_wesm = df_wesm.drop(['STATUS'],axis=1)
df_retail = df_retail.drop(['STATUS'],axis=1)

# %% [markdown]
# #### Visualisations

# %%
import os
import googlemaps
gmap = googlemaps.Client(key=os.getenv('GOOGLE_API_KEY'))

# %%
# Reset index since the rows dropped caused the index to skip integer sequence
df_wesm = df_wesm.reset_index(drop=True)

# %%
df_wesm.isnull().sum()
# Out:
# PARTICIPANT NAME    0
# SHORT NAME          0
# REGION              0
# CATEGORY            0
# MEMBERSHIP          0
# RESOURCE            0
# EFFECTIVE DATE      0
# dtype: int64

# %%
# Geocoding an address
#df_wesm_coded = pd.DataFrame({"PLACE":names})
df_wesm["LAT"] = None
df_wesm["LON"] = None
country_limit = {'country': 'Philippines'}
geocode_result = []

for i in range(0, len(df_wesm.index),1): 
    geocode_result = gmap.geocode(df_wesm['RESOURCE'][i],country_limit)
    
    if geocode_result: #meaning its successful
        pass
    else:
        geocode_result = gmap.geocode(df_wesm['PARTICIPANT NAME'][i] + ' ' + df_wesm['RESOURCE'][i],country_limit)

    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        df_wesm.iat[i,df_wesm.columns.get_loc("LAT")] = lat
        df_wesm.iat[i,df_wesm.columns.get_loc("LON")] = lon
    except Exception as e:
        #IndexError
        lat = None
        lon = None

# %%
df_wesm
# Out:
#                   PARTICIPANT NAME         SHORT NAME    REGION  \
# 0       GNPower Kauswagan Ltd. Co.            GNPKLCO  MINDANAO
# 1       GNPower Kauswagan Ltd. Co.            GNPKLCO  MINDANAO
# 2                  FGP Corporation  FGP - San Lorenzo     LUZON
# 3                  FGP Corporation  FGP - San Lorenzo     LUZON
# 4      First Gas Power Corporation           FGPCSTRA     LUZON
# ..                             ...                ...       ...
# 414  FDC Misamis Power Corporation                FDC  MINDANAO
# 415  FDC Misamis Power Corporation                FDC  MINDANAO
# 416  FDC Misamis Power Corporation                FDC  MINDANAO
# 417    Malvar Enerzone Corporation             MALVEZ     LUZON
# 418      GNPower Dinginin Ltd. Co.               GNPD     LUZON
#
#                          CATEGORY MEMBERSHIP  \
# 0                       GENERATOR     DIRECT
# 1                       GENERATOR     DIRECT
# 2                       GENERATOR     DIRECT
# 3                       GENERATOR     DIRECT
# 4                       GENERATOR     DIRECT
# ..                            ...        ...
# 414                     GENERATOR     DIRECT
# 415                     GENERATOR     DIRECT
# 416                     GENERATOR     DIRECT
# 417  PRIVATE DISTRIBUTION UTILITY     DIRECT
# 418                     GENERATOR     DIRECT
#
#                                          RESOURCE EFFECTIVE DATE      LAT  \
# 0              GNPK Coal Fired Power Plant Unit 4     2020-08-07  8.18565
# 1              GNPK Coal Fired Power Plant Unit 3     2020-08-07  8.18565
# 2           San Lorenzo Natural Gas Power Plant 5     2006-06-26  10.6046
# 3           San Lorenzo Natural Gas Power Plant 6     2006-06-26  13.7765
# 4             Sta. Rita Natural Gas Power Plant 1     2006-06-26  13.7765
# ..                                            ...            ...      ...
# 414  135 MW Coal Fired Thermal Power Plant Unit 1     2020-10-26  8.56104
# 415  135 MW Coal Fired Thermal Power Plant Unit 2     2020-10-26  8.56104
# 416  135 MW Coal Fired Thermal Power Plant Unit 3     2020-10-26  8.56104
# 417                   Malvar Enerzone Corporation     2020-10-30  14.0433
# 418                   GNPD Coal Fired Power Plant     2020-10-31  14.4249
#
#          LON
# 0    124.118
# 1    124.118
# 2    122.684
# 3    121.033
# 4    121.033
# ..       ...
# 414  124.748
# 415  124.748
# 416  124.748
# 417  121.159
# 418  120.537
#
# [419 rows x 9 columns]

# %%
df_wesm.to_csv('/Volumes/data/projects/data/philippine-energy-market/wholesale_participants.csv', index=False)

# %%
df_wesm[df_wesm['LON'].isnull()]
# Out:
#                                       PARTICIPANT NAME SHORT NAME    REGION  \
# 20   Power Sector Assets & Liabilities Management C...      PSALM  MINDANAO
# 159                  First Farmers Holding Corporation       FFHC   VISAYAS
# 202                     Embarcadero Land Ventures Inc.       ELVI     LUZON
# 223                           CIP II Power Corporation       CIP2     LUZON
# 224                                 Petron Corporation  PETRONGEN     LUZON
# 238       AP Renewables Inc. (APRI-Unocal Philippines)    APRICST     LUZON
# 256                       Universal Robina Corporation        URC   VISAYAS
# 258                       Majestics Energy Corporation        MEC     LUZON
# 266  Philippine Radio Educational and Information C...  PREIC-RVA     LUZON
# 273                      Montalban Methane Power Corp.       MMPC     LUZON
# 290                        AC Energy Philippines, Inc.       PHEN   VISAYAS
# 319        nv vogt Philippines Solar Energy Three Inc.  NVVOGTARM     LUZON
# 338                        AC Energy Philippines, Inc.       PHEN   VISAYAS
# 342                      SN Aboitiz Power - Magat Inc.       SNAP     LUZON
# 343                      SN Aboitiz Power - Magat Inc.       SNAP     LUZON
# 350                   Central Azucarera Don Pedro Inc.      CADPI     LUZON
# 362                          Therma Power Visayas Inc.       TPVI   VISAYAS
# 372                         South Negros Biopower Inc.       SNBP   VISAYAS
# 375                                 Hedcor Tudaya Inc.       HTI2  MINDANAO
# 378                                        Biscom Inc.     BISCOM   VISAYAS
# 379             Grassgold Renewable Energy Corporation      G2REC     LUZON
# 391                                 Therma Marine Inc.        TMI  MINDANAO
# 392                                 Therma Marine Inc.        TMI  MINDANAO
# 393                                 Therma Marine Inc.        TMI  MINDANAO
# 402                 Astronergy Development Gensan Inc.       ADGI  MINDANAO
#
#       CATEGORY MEMBERSHIP                                           RESOURCE  \
# 20   GENERATOR     DIRECT   80.46 MW Agus I Hydroelectric Power Plant Unit 2
# 159  GENERATOR     DIRECT       FFHC Co-Generation Bagasse-Fired Power Plant
# 202  BULK USER   INDIRECT                     Embarcadero Land Ventures Inc.
# 223  GENERATOR     DIRECT                      CIP2 Bunker-Fired Power Plant
# 224  GENERATOR     DIRECT              Circulating Fluidized Bed Power Plant
# 238  BULK USER   INDIRECT       AP Renewables Inc. (APRI-Unocal Philippines)
# 256  GENERATOR     DIRECT              URC Bagasse-Fired Biomass Power Plant
# 258  GENERATOR     DIRECT              Majestics Energy Solar PV Power Plant
# 266  BULK USER   INDIRECT  Philippine Radio Educational and Information C...
# 273  GENERATOR     DIRECT                           MMPC Biomass Power Plant
# 290  GENERATOR     DIRECT                                    Power Barge 101
# 319  GENERATOR     DIRECT                          Armenia Solar Power Plant
# 338  GENERATOR     DIRECT                                    Power Barge 103
# 342  GENERATOR     DIRECT                            Maris Canal HEPP Unit 1
# 343  GENERATOR     DIRECT                            Maris Canal HEPP Unit 2
# 350  GENERATOR     DIRECT                          CADPI Biomass Power Plant
# 362  GENERATOR     DIRECT             TPVI Bunker C-Fired Diesel Power Plant
# 372  GENERATOR     DIRECT                           SNBP Biomass Power Plant
# 375  GENERATOR     DIRECT                 Tudaya 2 Hydroelectric Power Plant
# 378  GENERATOR     DIRECT                         Biscom Biomass Power Plant
# 379  GENERATOR     DIRECT                          G2REC Biomass Power Plant
# 391  GENERATOR     DIRECT                                    Mobile 2 Unit 2
# 392  GENERATOR     DIRECT                                    Mobile 2 Unit 1
# 393  GENERATOR     DIRECT                                    Mobile 1 Unit 2
# 402  GENERATOR     DIRECT                 24.96 MWp Santos Solar Power Plant
#
#     EFFECTIVE DATE   LAT   LON
# 20      2020-04-25  None  None
# 159     2010-12-26  None  None
# 202     2011-11-26  None  None
# 223     2013-01-17  None  None
# 224     2013-03-13  None  None
# 238     2014-06-05  None  None
# 256     2014-12-18  None  None
# 258     2015-01-06  None  None
# 266     2015-04-18  None  None
# 273     2015-08-13  None  None
# 290     2016-01-26  None  None
# 319     2016-04-08  None  None
# 338     2017-06-09  None  None
# 342     2017-10-14  None  None
# 343     2017-10-14  None  None
# 350     2017-12-30  None  None
# 362     2019-05-04  None  None
# 372     2019-09-12  None  None
# 375     2019-09-24  None  None
# 378     2019-11-09  None  None
# 379     2019-11-15  None  None
# 391     2020-01-08  None  None
# 392     2020-01-08  None  None
# 393     2020-01-08  None  None
# 402     2020-03-27  None  None

# %%
df_wesm['LON'].isnull().sum()
# Out:
# 25

# %% [markdown]
# ---

# %% [markdown]
# ### Retail Market
#
# This section discusses the Retail Market participants.

# %%
df_retail.columns
# Out:
# Index(['NAME', 'SHORT NAME', 'REGION', 'CATEGORY', 'MEMBERSHIP',
#        'EFFECTIVE DATE', 'STATUS'],
#       dtype='object')

# %%
df_retail['CATEGORY'].unique()
# Out:
# array(['Contestable Customer', 'Retail Metering Services Provider',
#        'Local Retail Electricity Supplier', 'Supplier of Last Resort',
#        'Directly Connected Contestable Customer',
#        'Retail Electricity Supplier'], dtype=object)

# %%
df_retail[df_retail['CATEGORY'] =='Contestable Customer'].head().style.set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7a th {
#           font-size: 80%;
#     }    #T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7a td {
#           font-size: 80%;
#     }</style><table id="T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >NAME</th>        <th class="col_heading level0 col1" >SHORT NAME</th>        <th class="col_heading level0 col2" >REGION</th>        <th class="col_heading level0 col3" >CATEGORY</th>        <th class="col_heading level0 col4" >MEMBERSHIP</th>        <th class="col_heading level0 col5" >EFFECTIVE DATE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T
el0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7arow4_col0" class="data row4 col0" >Marina Square Properties Inc.</td>
#                         <td id="T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7arow4_col1" class="data row4 col1" >MSPI01R</td>
#                         <td id="T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7arow4_col2" class="data row4 col2" >Luzon</td>
#                         <td id="T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7arow4_col3" class="data row4 col3" >Contestable Customer</td>
#                         <td id="T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7arow4_col4" class="data row4 col4" >Indirect</td>
#                         <td id="T_9b23bcc8_2ae0_11eb_ba32_8c2937e74e7arow4_col5" class="data row4 col5" >2013-06-26 00:00:00</td>
#             </tr>
#     </tbody></table>

# %%
# Removing non-ascii character on line 380
df_retail['NAME'] = df_retail["NAME"].apply(lambda x: ''.join([" " if ord(i) < 32 or ord(i) > 126 else i for i in x]))

# %%
# Reset index since the rows dropped caused the index to skip integer sequence
df_retail = df_retail.reset_index(drop=True)

# %%
df_retail.describe
# Out:
# <bound method NDFrame.describe of                                                    NAME SHORT NAME   REGION  \
# 0                                 Styrotech Corporation    STYR01R    Luzon
# 1                        Analog Devices Gen. Trias Inc.    ADGT01R    Luzon
# 2                        Analog Devices Gen. Trias Inc.    ADGT02R    Luzon
# 3                                    Ascott Makati Inc.    ATMK01R    Luzon
# 4                         Marina Square Properties Inc.    MSPI01R    Luzon
# ...                                                 ...        ...      ...
# 1617                     ANGELICA DL MOJICA CORPORATION    ADLMC1R    Luzon
# 1618                              POLYTEX LAIWELL, INC.    PLYTX1R    Luzon
# 1619  Dynasty Management and Development Corp. (Gais...    DMDC06R  Visayas
# 1620                                Sunpride Foods Inc.    SNPFI1R  Visayas
# 1621                   Capiz Electric Cooperative, Inc.  CAPELCMSP  Visayas
#
#                                CATEGORY        MEMBERSHIP EFFECTIVE DATE  \
# 0                  Contestable Customer          Indirect     2013-06-26
# 1                  Contestable Customer          Indirect     2013-06-26
# 2                  Contestable Customer          Indirect     2013-06-26
# 3                  Contestable Customer          Indirect     2013-06-26
# 4                  Contestable Customer          Indirect     2013-06-26
# ...                                 ...               ...            ...
# 1617               Contestable Customer          Indirect     2020-10-26
# 1618               Contestable Customer          Indirect     2020-10-26
# 1619               Contestable Customer          Indirect     2020-10-26
# 1620               Contestable Customer          Indirect     2020-10-26
# 1621  Retail Metering Services Provider  Service Provider     2020-11-11
#
#           LAT      LON
# 0     14.7533   120.99
# 1     14.2632   120.92
# 2     14.2632   120.92
# 3     14.5511  121.026
# 4     14.5731  120.983
# ...       ...      ...
# 1617     None     None
# 1618     None     None
# 1619     None     None
# 1620     None     None
# 1621     None     None
#
# [1622 rows x 8 columns]>

# %%
df_retail.isnull().sum()
# Out:
# NAME                 0
# SHORT NAME           0
# REGION               0
# CATEGORY             0
# MEMBERSHIP           0
# EFFECTIVE DATE       0
# LAT               1282
# LON               1282
# dtype: int64

# %%
# Geocoding an address
df_retail["LAT"] = None
df_retail["LON"] = None
country_limit = {'country': 'Philippines'}
geocode_result = []

for i in range(0, len(df_retail.index),1): 
    geocode_result = gmap.geocode(df_retail['NAME'][i],country_limit)
    
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        df_retail.iat[i,df_retail.columns.get_loc("LAT")] = lat
        df_retail.iat[i,df_retail.columns.get_loc("LON")] = lon
    except Exception as e:
        #IndexError
        lat = None
        lon = None

# %%
df_retail
# Out:
#                                                    NAME SHORT NAME   REGION  \
# 0                                 Styrotech Corporation    STYR01R    Luzon
# 1                        Analog Devices Gen. Trias Inc.    ADGT01R    Luzon
# 2                        Analog Devices Gen. Trias Inc.    ADGT02R    Luzon
# 3                                    Ascott Makati Inc.    ATMK01R    Luzon
# 4                         Marina Square Properties Inc.    MSPI01R    Luzon
# ...                                                 ...        ...      ...
# 1617                     ANGELICA DL MOJICA CORPORATION    ADLMC1R    Luzon
# 1618                              POLYTEX LAIWELL, INC.    PLYTX1R    Luzon
# 1619  Dynasty Management and Development Corp. (Gais...    DMDC06R  Visayas
# 1620                                Sunpride Foods Inc.    SNPFI1R  Visayas
# 1621                   Capiz Electric Cooperative, Inc.  CAPELCMSP  Visayas
#
#                                CATEGORY        MEMBERSHIP EFFECTIVE DATE  \
# 0                  Contestable Customer          Indirect     2013-06-26
# 1                  Contestable Customer          Indirect     2013-06-26
# 2                  Contestable Customer          Indirect     2013-06-26
# 3                  Contestable Customer          Indirect     2013-06-26
# 4                  Contestable Customer          Indirect     2013-06-26
# ...                                 ...               ...            ...
# 1617               Contestable Customer          Indirect     2020-10-26
# 1618               Contestable Customer          Indirect     2020-10-26
# 1619               Contestable Customer          Indirect     2020-10-26
# 1620               Contestable Customer          Indirect     2020-10-26
# 1621  Retail Metering Services Provider  Service Provider     2020-11-11
#
#           LAT      LON
# 0     14.7533   120.99
# 1     14.2632   120.92
# 2     14.2632   120.92
# 3     14.5511  121.026
# 4     14.5731  120.983
# ...       ...      ...
# 1617  14.6512  121.103
# 1618  14.6392  121.005
# 1619  10.3321  123.936
# 1620  10.3445  123.952
# 1621  11.5871  122.753
#
# [1622 rows x 8 columns]

# %%
i
# Out:
# 1621

# %%
df_retail.to_csv('/Volumes/data/projects/data/philippine-energy-market/retail_participants.csv', index=False)

# %%
df_retail_null = df_retail[df_retail['LON'].isnull()]
df_retail_null = df_retail_null.reset_index(drop=True)

# %%
df_retail_null.groupby('REGION')['NAME'].nunique()
# Out:
# REGION
# Luzon            110
# Luzon/Visayas      7
# Visayas           14
# Name: NAME, dtype: int64

# %%
df_retail_null.groupby('CATEGORY')['NAME'].nunique()
# Out:
# CATEGORY
# Contestable Customer                       119
# Directly Connected Contestable Customer      3
# Retail Electricity Supplier                  7
# Name: NAME, dtype: int64

# %%
df_retail_null[df_retail_null["CATEGORY"]=="Retail Electricity Supplier"]
# Out:
#                                           NAME SHORT NAME         REGION  \
# 22                   Millennium Power RES Inc.    MPRIRES  Luzon/Visayas
# 28                              Corenergy Inc.    CORERES  Luzon/Visayas
# 100                             MeridianX Inc.    MERXRES  Luzon/Visayas
# 126  Solar Philippines Retail Electricity Inc.   SPREIRES  Luzon/Visayas
# 133              PHINMA Energy Corporation-RES    PHENRES  Luzon/Visayas
# 134                          Prism Energy Inc.   PRISMRES  Luzon/Visayas
# 135              Ecozone Power Management Inc.    EPMIRES  Luzon/Visayas
#
#                         CATEGORY MEMBERSHIP EFFECTIVE DATE   LAT   LON
# 22   Retail Electricity Supplier     Direct     2016-08-18  None  None
# 28   Retail Electricity Supplier     Direct     2016-12-23  None  None
# 100  Retail Electricity Supplier     Direct     2019-03-04  None  None
# 126  Retail Electricity Supplier     Direct     2020-02-18  None  None
# 133  Retail Electricity Supplier     Direct     2013-02-19  None  None
# 134  Retail Electricity Supplier     Direct     2013-03-15  None  None
# 135  Retail Electricity Supplier     Direct     2013-06-17  None  None

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df_retail_null['NAME'] = df_retail_null['NAME'].str.strip()  # or .replace as above

# %%
#Limited to 2,500 API calls per day
df_retail_null
# Out:
#                                                   NAME SHORT NAME REGION  \
# 0                            Midland Steel Corporation    MSC002R  Luzon
# 1                              Sureste Properties Inc.    SPI001R  Luzon
# 2                        St. Lukes Medical Center Inc.    SLH001R  Luzon
# 3                         Jollibee Worldwide Pte. Ltd.    JWL001R  Luzon
# 4                             Philippine Airlines Inc.    PAL001R  Luzon
# ..                                                 ...        ...    ...
# 151        Philippine Integrated Energy Solutions Inc.    PIES02R  Luzon
# 152  Maxi Peak Property Development and Management ...    MAXIP1R  Luzon
# 153                      Chuangxing Steel Incorporated    CXSTL1R  Luzon
# 154                       Ground 18 Realty Corporation    GRD181R  Luzon
# 155                     Ayala Land, Inc. (Circuit DCS)    ALI108R  Luzon
#
#                  CATEGORY MEMBERSHIP EFFECTIVE DATE   LAT   LON
# 0    Contestable Customer   Indirect     2013-06-26  None  None
# 1    Contestable Customer   Indirect     2013-12-26  None  None
# 2    Contestable Customer   Indirect     2014-01-26  None  None
# 3    Contestable Customer   Indirect     2014-02-26  None  None
# 4    Contestable Customer   Indirect     2014-03-26  None  None
# ..                    ...        ...            ...   ...   ...
# 151  Contestable Customer   Indirect     2013-06-26  None  None
# 152  Contestable Customer   Indirect     2020-08-26  None  None
# 153  Contestable Customer   Indirect     2020-08-26  None  None
# 154  Contestable Customer   Indirect     2020-10-26  None  None
# 155  Contestable Customer   Indirect     2020-10-26  None  None
#
# [156 rows x 8 columns]

# %%
gmap.geocode(df_retail_null['NAME'][1] +' '+ 'Philippines')
# Out:
# []

# %%
df_retail_null['NAME'][1] +' '+ 'Philippines'
# Out:
# 'Sureste Properties Inc. Philippines'

# %%
country_limit = {'country': 'Philippines'}
