# %%
import pandas as pd

# %%
datapath = '/Volumes/data/projects/django-mms/mms/pricesandschedules/sampledata/RTD_2021-06-16_2021-06-16_G_LUZON.csv'

# %%
reader = pd.read_csv(path, usecols = range(8),  header=3)

# %%
reader.head()
# Out:
#   DELIVERY_DATE  DELIVERY_HOUR REGION_ID TYPE_ID PARTICIPANT_ID  RESOURCE_ID  \
# 0    06/16/2021            1.0     LUZON     GEN         1590EC  1BAUANG_GS1
# 1    06/16/2021            1.0     LUZON     GEN         1590EC  1BAUANG_GS2
# 2    06/16/2021            1.0     LUZON     GEN         1590EC  1BAUANG_GS3
# 3    06/16/2021            1.0     LUZON     GEN      ABSOLUTDI  3ADISOL_G01
# 4    06/16/2021            1.0     LUZON     GEN            AHC     1ANGAT_A
#
#      MW    PRICE
# 0   0.0  2969.26
# 1   0.0  2969.26
# 2   0.0  2969.26
# 3   0.0  2883.11
# 4  12.9  2985.21

# %%
reader.columns
# Out:
# Index(['DELIVERY_DATE', 'DELIVERY_HOUR', 'REGION_ID', 'TYPE_ID',
#        'PARTICIPANT_ID', 'RESOURCE_ID', 'MW', 'PRICE'],
#       dtype='object')

# %%
reader.shape[0]-1
# Out:
# 3620

# %%
reader = reader.drop(reader.index[reader.shape[0]-1])

# %%
reader.iloc[3619]
# Out:
# DELIVERY_DATE     06/16/2021
# DELIVERY_HOUR             24
# REGION_ID              LUZON
# TYPE_ID                  GEN
# PARTICIPANT_ID         YHGEI
# RESOURCE_ID       1YHGRN_G01
# MW                         0
# PRICE                2977.67
# Name: 3619, dtype: object

# %%
def format_date(date):
    month  = date.split('/')[0]
    day = date.split('/')[1]
    year  = date.split('/')[2]
    return '%s-%s-%s' % (year, month, day)

# %%
reader['DELIVERY_DATE']
# Out:
# 0       06/16/2021
# 1       06/16/2021
# 2       06/16/2021
# 3       06/16/2021
# 4       06/16/2021
#            ...
# 3615    06/16/2021
# 3616    06/16/2021
# 3617    06/16/2021
# 3618    06/16/2021
# 3619    06/16/2021
# Name: DELIVERY_DATE, Length: 3620, dtype: object

# %%
reader['DELIVERY_DATE'] =  pd.to_datetime(reader['DELIVERY_DATE'])

# %%
reader['DELIVERY_DATE']
# Out:
# 0      2021-06-16
# 1      2021-06-16
# 2      2021-06-16
# 3      2021-06-16
# 4      2021-06-16
#           ...
# 3615   2021-06-16
# 3616   2021-06-16
# 3617   2021-06-16
# 3618   2021-06-16
# 3619   2021-06-16
# Name: DELIVERY_DATE, Length: 3620, dtype: datetime64[ns]

# %%
reader
# Out:
#      DELIVERY_DATE  DELIVERY_HOUR REGION_ID TYPE_ID PARTICIPANT_ID  \
# 0       2021-06-16            1.0     LUZON     GEN         1590EC
# 1       2021-06-16            1.0     LUZON     GEN         1590EC
# 2       2021-06-16            1.0     LUZON     GEN         1590EC
# 3       2021-06-16            1.0     LUZON     GEN      ABSOLUTDI
# 4       2021-06-16            1.0     LUZON     GEN            AHC
# ...            ...            ...       ...     ...            ...
# 3615    2021-06-16           24.0     LUZON     GEN           WESM
# 3616    2021-06-16           24.0     LUZON     GEN           WESM
# 3617    2021-06-16           24.0     LUZON     GEN           WESM
# 3618    2021-06-16           24.0     LUZON     GEN           WESM
# 3619    2021-06-16           24.0     LUZON     GEN          YHGEI
#
#       RESOURCE_ID    MW    PRICE
# 0     1BAUANG_GS1   0.0  2969.26
# 1     1BAUANG_GS2   0.0  2969.26
# 2     1BAUANG_GS3   0.0  2969.26
# ...

# %%
for index, row in reader.iterrows():
    print(row[0])
# Out:
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# 2021-06-16 00:00:00
# ...

# %%
reader.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x7fda162de6d0>
