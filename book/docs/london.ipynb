# %% [markdown]
# # Residential demand data

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import svm

# %%
filepath = "/Volumes/data/projects/data/london-data/london-data.csv"

# %%
df = pd.read_csv(filepath)

# %%
df.head()
# Out:
#    HOUSEHOLD    ACORN ACORN_GROUPED TARIFF         0         3        10  \
# 0  MAC000002  ACORN-A      Affluent    Std  0.271369  0.247060  0.225293
# 1  MAC000003  ACORN-P     Adversity    Std  1.794727  1.785644  1.312079
# 2  MAC000004  ACORN-E      Affluent    Std  0.036151  0.026742  0.034912
# 3  MAC000005  ACORN-C      Affluent    ToU  0.042350  0.035658  0.034334
# 4  MAC000006  ACORN-Q     Adversity    Std  0.035318  0.032890  0.031148
#
#          13        20        23  ...       190       193       200       203  \
# 0  0.187364  0.163408  0.137003  ...  0.546030  0.428592  0.530795  0.380178
# 1  0.727622  0.879575  0.733532  ...  0.198252  0.185792  0.188959  0.156384
# 2  0.035405  0.039047  0.037088  ...  0.029129  0.033742  0.038468  0.041784
# 3  0.033811  0.033266  0.033395  ...  0.140956  0.125515  0.122282  0.133573
# 4  0.029422  0.030444  0.029348  ...  0.091699  0.093334  0.091778  0.092011
#
#         210       213       220       223       230       233
# 0  0.345241  0.339548  0.332214  0.327674  0.305082  0.286737
# 1  0.148044  0.132761  0.130312  0.131195  0.114351  0.098274
# 2  0.035860  0.034740  0.031449  0.034573  0.038751  0.036970
# 3  0.167329  0.168315  0.145066  0.129637  0.090162  0.061986
# 4  0.089918  0.078537  0.072682  0.060775  0.048392  0.042789
#
# [5 rows x 52 columns]
