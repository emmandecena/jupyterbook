# %% [markdown]
# # IEMOP data exporation

# %%
# Libraries
import pandas as pd
import numpy as np

# %%
#import os
#os.system("""awk '(NR == 1) || !/^EOF/ && (FNR > 1)' /Volumes/data/projects/django-mms/tempdata/20210704/RTD*.csv > /Volumes/data/projects/django-mms/tempdata/20210704/bigfile.csv""")

# %%
fname = "/Volumes/data/projects/django-mms/tempdata/20210704/bigfile.csv"

# %%
df = pd.read_csv(fname)
df.head()
# Out:
#            RUN_TIME MKT_TYPE     TIME_INTERVAL REGION_NAME RESOURCE_NAME  \
# 0  2021-07-04 00:00      RTD  2021-07-04 00:05        CLUZ   01ACNPC_G01
# 1  2021-07-04 00:00      RTD  2021-07-04 00:05        CLUZ     01AEC_L01
# 2  2021-07-04 00:00      RTD  2021-07-04 00:05        CLUZ    01AMBUK_SS
# 3  2021-07-04 00:00      RTD  2021-07-04 00:05        CLUZ  01AMBUK_T1L1
# 4  2021-07-04 00:00      RTD  2021-07-04 00:05        CLUZ   01AMBUK_U01
#
#   RESOURCE_TYPE  SCHED_MW           LMP  LOSS_FACTOR       LMP_SMP  \
# 0             G    0.0000  22863.792773     0.991213  22662.100082
# 1            NL  -38.4587  22893.253503     0.989911  22662.100082
# 2            NL    0.0000  22757.280902     0.995825  22662.100082
# 3            NL    0.0000  22757.280902     0.995825  22662.100082
# 4             G   24.0000  22752.748482     0.996039  22662.100082
#
#      LMP_LOSS  LMP_CONGESTION
# 0  201.692691             0.0
# 1  231.153421             0.0
# 2   95.180820             0.0
# 3   95.180820             0.0
# 4   90.648400             0.0

# %%
df.groupby(['REGION_NAME']).count()
# Out:
#              RUN_TIME  MKT_TYPE  TIME_INTERVAL  RESOURCE_NAME  RESOURCE_TYPE  \
# REGION_NAME
# CLUZ           125568    125568         125568         125568         125568
# CMIN            61056     61056          61056          61056          61056
# CVIS            60480     60480          60480          60480          60480
#
#              SCHED_MW     LMP  LOSS_FACTOR  LMP_SMP  LMP_LOSS  LMP_CONGESTION
# REGION_NAME
# CLUZ           125568  125568       125568   125568    125568          125568
# CMIN            61056   61056        61056    61056     61056           61056
# CVIS            60480   60480        60480    60480     60480           60480

# %%
df.groupby(['RESOURCE_NAME']).count()
# Out:
#                RUN_TIME  MKT_TYPE  TIME_INTERVAL  REGION_NAME  RESOURCE_TYPE  \
# RESOURCE_NAME
# 01ACNPC_G01         288       288            288          288            288
# 01AEC_L01           288       288            288          288            288
# 01AMBUK_SS          288       288            288          288            288
# 01AMBUK_T1L1        288       288            288          288            288
# 01AMBUK_U01         288       288            288          288            288
# ...                 ...       ...            ...          ...            ...
# 14SRL_T1L1          288       288            288          288            288
# 14SUPKOR_G01        288       288            288          288            288
# 14SX3_T1L1          288       288            288          288            288
# 14TIN_T1L1          288       288            288          288            288
# 14TIN_T1L2          288       288            288          288            288
#
#                SCHED_MW  LMP  LOSS_FACTOR  LMP_SMP  LMP_LOSS  LMP_CONGESTION
# RESOURCE_NAME
# 01ACNPC_G01         288  288          288      288       288             288
# 01AEC_L01           288  288          288      288       288             288
# 01AMBUK_SS          288  288          288      288       288             288
# 01AMBUK_T1L1        288  288          288      288       288             288
# 01AMBUK_U01         288  288          288      288       288             288
# ...                 ...  ...          ...      ...       ...             ...
# 14SRL_T1L1          288  288          288      288       288             288
# 14SUPKOR_G01        288  288          288      288       288             288
# 14SX3_T1L1          288  288          288      288       288             288
# 14TIN_T1L1          288  288          288      288       288             288
# 14TIN_T1L2          288  288          288      288       288             288
#
# [858 rows x 11 columns]

# %%
df[df['REGION_NAME']=='CVIS'].groupby(['RESOURCE_NAME']).count()
# Out:
#                RUN_TIME  MKT_TYPE  TIME_INTERVAL  REGION_NAME  RESOURCE_TYPE  \
# RESOURCE_NAME
# 04BABAT_SS          288       288            288          288            288
# 04BABAT_T1L1        288       288            288          288            288
# 04BAGLI_T1L1        288       288            288          288            288
# 04CLBYOG_L01        288       288            288          288            288
# 04CLBYOG_L02        288       288            288          288            288
# ...                 ...       ...            ...          ...            ...
# 08STBAR_SS3         288       288            288          288            288
# 08STBAR_T1L1        288       288            288          288            288
# 08STBAR_T2L2        288       288            288          288            288
# 08STBAR_T3L3        288       288            288          288            288
# 08SUWECO_G01        288       288            288          288            288
#
#                SCHED_MW  LMP  LOSS_FACTOR  LMP_SMP  LMP_LOSS  LMP_CONGESTION
# RESOURCE_NAME
# 04BABAT_SS          288  288          288      288       288             288
# 04BABAT_T1L1        288  288          288      288       288             288
# 04BAGLI_T1L1        288  288          288      288       288             288
# 04CLBYOG_L01        288  288          288      288       288             288
# 04CLBYOG_L02        288  288          288      288       288             288
# ...                 ...  ...          ...      ...       ...             ...
# 08STBAR_SS3         288  288          288      288       288             288
# 08STBAR_T1L1        288  288          288      288       288             288
# 08STBAR_T2L2        288  288          288      288       288             288
# 08STBAR_T3L3        288  288          288      288       288             288
# 08SUWECO_G01        288  288          288      288       288             288
#
# [210 rows x 11 columns]

# %%
import seaborn as sns

# %%
PLANTS = ['05CEDC_U01', '05CEDC_U02', '05CEDC_U03']

df[df['RESOURCE_NAME'].isin(PLANTS)]
# Out:
#                 RUN_TIME MKT_TYPE     TIME_INTERVAL REGION_NAME RESOURCE_NAME  \
# 480     2021-07-04 00:00      RTD  2021-07-04 00:05        CVIS    05CEDC_U01
# 481     2021-07-04 00:00      RTD  2021-07-04 00:05        CVIS    05CEDC_U02
# 482     2021-07-04 00:00      RTD  2021-07-04 00:05        CVIS    05CEDC_U03
# 1338    2021-07-04 00:05      RTD  2021-07-04 00:10        CVIS    05CEDC_U01
# 1339    2021-07-04 00:05      RTD  2021-07-04 00:10        CVIS    05CEDC_U02
# ...                  ...      ...               ...         ...           ...
# 245869  2021-07-04 23:50      RTD  2021-07-04 23:55        CVIS    05CEDC_U02
# 245870  2021-07-04 23:50      RTD  2021-07-04 23:55        CVIS    05CEDC_U03
# 246726  2021-07-04 23:55      RTD  2021-07-05 00:00        CVIS    05CEDC_U01
# 246727  2021-07-04 23:55      RTD  2021-07-05 00:00        CVIS    05CEDC_U02
# 246728  2021-07-04 23:55      RTD  2021-07-05 00:00        CVIS    05CEDC_U03
#
#        RESOURCE_TYPE   SCHED_MW          LMP  LOSS_FACTOR      LMP_SMP  \
# 480                G  72.000000  3253.940436     1.027436  3343.203982
# 481                G  72.000000  3253.940436     1.027436  3343.203982
# 482                G  72.000000  3253.940436     1.027436  3343.203982
# 1338               G  72.000000  3253.940436     1.027398  3343.203982
# 1339               G  72.000000  3253.940436     1.027398  3343.203982
# ...              ...        ...          ...          ...          ...
# 245869             G  67.194723  2153.540000     1.024841  2206.948145
# 245870             G  67.194723  2153.540000     1.024841  2206.948145
# 246726             G  68.959686  2153.540000     1.025683  2208.758974
# 246727             G  68.959686  2153.540000     1.025683  2208.758974
# 246728             G  68.959686  2153.540000     1.025683  2208.758974
#
#          LMP_LOSS  LMP_CONGESTION
# 480    -89.263546             0.0
# 481    -89.263546             0.0
# 482    -89.263546             0.0
# 1338   -89.263546             0.0
# 1339   -89.263546             0.0
# ...           ...             ...
# 245869 -53.408145             0.0
# 245870 -53.408145             0.0
# 246726 -55.218974             0.0
# 246727 -55.218974             0.0
# 246728 -55.218974             0.0
#
# [864 rows x 12 columns]

# %%
df.groupby(['RUN_TIME', 'REGION_NAME']).mean().reset_index()
# Out:
#              RUN_TIME REGION_NAME  SCHED_MW           LMP  LOSS_FACTOR  \
# 0    2021-07-04 00:00        CLUZ -0.379358  22545.083601     1.005720
# 1    2021-07-04 00:00        CMIN  0.156180  33190.711117     0.980470
# 2    2021-07-04 00:00        CVIS  2.274147   3366.775162     0.997716
# 3    2021-07-04 00:05        CLUZ -0.384808  32101.945875     1.009008
# 4    2021-07-04 00:05        CMIN  0.144129  27668.076182     0.984083
# ..                ...         ...       ...           ...          ...
# 859  2021-07-04 23:50        CMIN  0.185727   1048.071326     0.968867
# 860  2021-07-04 23:50        CVIS  1.954429   2312.368803     0.956363
# 861  2021-07-04 23:55        CLUZ -0.302223   2206.185973     1.001655
# 862  2021-07-04 23:55        CMIN  0.178955   1047.034519     0.969139
# 863  2021-07-04 23:55        CVIS  2.056143   2326.438497     0.951456
#
#           LMP_SMP    LMP_LOSS  LMP_CONGESTION
# 0    22662.100082 -117.016481             0.0
# 1    32418.194712  772.516405             0.0
# 2     3343.203982   23.571180             0.0
# 3    32375.556455 -273.610580             0.0
# 4    27151.015822  517.060359             0.0
# ..            ...         ...             ...
# 859   1008.268043   39.803283             0.0
# 860   2206.948145  105.420658             0.0
# 861   2208.758974   -2.573002             0.0
# 862   1008.166376   38.868143             0.0
# 863   2208.758974  117.679523             0.0
#
# [864 rows x 8 columns]

# %%
from matplotlib import pyplot
dims = (25, 10)

# %%
fig, ax = pyplot.subplots(figsize=dims)
sns.lineplot(data=df.groupby(['RUN_TIME', 'REGION_NAME']).mean().reset_index(), x="RUN_TIME", y="LMP", hue="REGION_NAME")
# Out:
# <AxesSubplot:xlabel='RUN_TIME', ylabel='LMP'>
